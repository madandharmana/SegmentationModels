# %%
#####################################################################################################################################################
#####################################################################################################################################################
################################ PROGRAM TO PERFORM EXPLORATORY DATA ANALYSIS ON MALL CUSTOMER DATA #################################################
#####################################################################################################################################################
#####################################################################################################################################################

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
###################################################### Read Mall Customer Data #####################################################################
customer_df = pd.read_csv('../data/Mall_Customers.csv')
customer_df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
############################################# Review Customers by Age vs Spending Score ############################################################
plt.scatter(customer_df["Age"], 
            customer_df["Spending Score (1-100)"])
plt.xlabel("Age")
plt.ylabel("Spending Score (1-100)")
# Out:
# Text(0, 0.5, 'Spending Score (1-100)')

# %%
############################################# Review Customers by Age vs Annual Income ############################################################
plt.scatter(customer_df["Age"], 
            customer_df["Annual Income (k$)"])

plt.xlabel("Age")
plt.ylabel("Annual Income (k$)")
# Out:
# Text(0, 0.5, 'Annual Income (k$)')

# %%
################################### Review Customers by Spending Score vs Annual Income ##########################################################
plt.scatter(customer_df["Spending Score (1-100)"], 
            customer_df["Annual Income (k$)"])
plt.xlabel("Spending Score (1-100)")
plt.ylabel("Annual Income (k$)")
# Out:
# Text(0, 0.5, 'Annual Income (k$)')

# %%
# Check for null values
customer_df.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64
